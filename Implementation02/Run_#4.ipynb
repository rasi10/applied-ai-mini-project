# %% [markdown]
# ### Introduction

# %% [markdown]
# In this run we demonstrate Transfer Learning
#
# We use two preprocessed datasets:
#
# - Dataset 1 (100% of images)
# - Dataset 2 (limited to 6% of the unique images per class in order to have reasonably fast execution times and similar sie to Dataset1)
#
# and ResNet50V2 base model for our CNN
#
# For each dataset we then train end evaluate the model for three different Random Seeds. We create a custom Seed Generator that can give numpy.random.seed() integer values based on Str values as the sum of the ASCII code of each leter of the String.
#
# Then present graphs of traning history metrics of each run and performance reports for each training

# %% [markdown]
# ### Importing modules

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import time
import itertools
import pickle
import os

from IPython.display import clear_output

from sklearn.metrics import confusion_matrix , classification_report, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D , MaxPooling2D , Dense , BatchNormalization , Dropout,Flatten , Activation
from tensorflow.keras import regularizers

import tensorflow_addons as tfa

from tensorflow import keras
from keras.applications import ResNet50V2
from keras.layers import Dense, Flatten, GlobalAveragePooling2D, Dropout
from keras.optimizers import Adam
from keras.models import Sequential
from keras.callbacks import EarlyStopping, ReduceLROnPlateau


sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Constants

# %%
# DIRECTORIES

DATASET = []
DATASET.append("./dataset1/brain_tumor_dataset_pp")
DATASET.append("./dataset2/Brain Tumor Data Set/Brain Tumor Data Set_pp006")

DATASET_PP = []
TRAIN_PATH = []
TEST_PATH = []
CLASS_LABELS = []
NUM_OF_CLASSES = []

for ii, ds in enumerate(DATASET):
    DATASET_PP.append(ds)
    TRAIN_PATH.append(ds + "/Train")
    TEST_PATH.append(ds + "/Test")
    CLASS_LABELS.append([filename for filename in os.listdir(TRAIN_PATH[ii]) if os.path.isdir(os.path.join(TRAIN_PATH[ii], filename))])
    
    NUM_OF_CLASSES.append(len(CLASS_LABELS[ii]))


# OTHER

IMG_SIZE = (244, 244)
BATCH_SIZE = 32

# %%
r_seeds = ["Georgios", "Rafael", "Dimitra"]

# %% [markdown]
# ## Function Definitions

# %% [markdown]
# ### Data Augmentation

# %%
def data_augmentation(r, s):
    # here we will define just the ImageDataGenrator
    # with 0 as the validation split to keep all the images of the traindataset
    # as currently in the train directory
    # we will split this to train-validation sets within the KFold loop

    random.seed(r)

    trn_datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split=s,
        rotation_range=20,          # randomly rotate the images by 20 degrees
        zoom_range=0.2,             # randomly zoom in/out on the images by 20%
        horizontal_flip=True,       # randomly flip the images horizontally
        vertical_flip=False,        # don't flip the images vertically
        width_shift_range=0.1,      # randomly shift the images horizontally by 10%
        height_shift_range=0.1,     # randomly shift the images vertically by 10%
        shear_range=0.1,            # apply random shear transformations
        fill_mode='nearest'         # fill in any empty pixels with the nearest available pixel
        )
    
    return trn_datagen

# %%
def test_data(tst_path, idx, img_size, batch_size):
    # and we can also define the test generator

    tst_datagen = ImageDataGenerator(rescale=1./255)


    tst_generator = tst_datagen.flow_from_directory(tst_path[idx],
                                                    target_size=img_size,
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
    return tst_generator

# %%
def plot_train_history(h, save2f = ''):
    
    hm=['loss', 'accuracy', 'f1_score', 'val_loss', 'val_accuracy', 'val_f1_score']
    e = len(h.history['loss'])

    # Plot metric values for the current seed
    plt.figure(figsize=(12, 6))

    for i in range(6):
        plt.subplot(2, 3, i+1)
        plt.plot(range(1, e+1), h.history[hm[i]], label=hm[i])
        plt.title(hm[i])
        plt.xticks([])
        
        
    plt.tight_layout()
    
    if save2f != '':
        plt.savefig("outputs/" + save2f + ".png")

    plt.show()

# %%
def plot_training_histories(seed_data, save2f=''):
    
    hm=['loss', 'accuracy', 'f1_score', 'val_loss', 'val_accuracy', 'val_f1_score']
    
    for sd in list(seed_data.keys()):
        for dset in list(seed_data[sd].keys()):
            print(f"Seed = {sd} | Dataset index: {dset}")
            h = seed_data[sd][dset][1]
          
            e = len(h.history['loss'])

            # Plot metric values for the current seed
            plt.figure(figsize=(12, 6))

            for i in range(6):
                plt.subplot(2, 3, i+1)
                plt.plot(range(1, e+1), h.history[hm[i]], label=hm[i])
                plt.title(f"{sd} > ds idx : {dset} > {hm[i]}")
                plt.xticks([])
                plt.tight_layout()
                
                if save2f != '':
                    plt.savefig("outputs/" + save2f + ".png")

            plt.show()

# %%
def string_to_int(my_seed):
    
    if isinstance(my_seed, str):
        ascii_values = 0
        for char in my_seed:
            ascii_values += ord(char)
        return int(ascii_values)
    else:
        return my_seed

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## Base Model : ResNet50v2

# %% [markdown]
# ### Model definition

# %%
def my_ResNet_model(c, show_summary=False):
    tf.keras.backend.clear_session()

    base_model = ResNet50V2(input_shape=IMG_SIZE+(3,), include_top=False)
    base_model.trainable = False

    mymodel = Sequential([base_model, 
                          GlobalAveragePooling2D(),
                          Flatten(),
                          Dense(256, activation="relu", kernel_initializer='he_normal'),
                          Dropout(0.3),
                          Dense(c, activation='softmax')
                          ])

    mymodel.compile(optimizer=Adam(), 
                    loss='categorical_crossentropy', 
                    metrics=['accuracy',
                             tf.keras.metrics.Precision(),
                             tf.keras.metrics.Recall(),
                             tf.keras.metrics.AUC(),
                             tfa.metrics.F1Score(num_classes=c, average='macro')
                             ])
    
    if show_summary:
        mymodel.summary()
    
    return mymodel

# %%
# show an example of a model summary for 2 classes
my_ResNet_model(2, show_summary=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 8, 8, 2048)        23564800
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 24089858 (91.90 MB)
# Trainable params: 525058 (2.00 MB)
# Non-trainable params: 23564800 (89.89 MB)
# _________________________________________________________________

# %% [markdown]
# ### Model training for different seeds and datasets

# %%
seed_results = {}

for rs in r_seeds:
    
    ds_results = {}

    for ds_idx in range(len(DATASET)):
        
        start_time = time.time()

        random.seed(rs)
        
        print(f"\n################################################################################### Seed: {rs} | DS: {ds_idx}")
        
        print(f"\n::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)")

        train_datagen = data_augmentation(rs, 0.2) 
        
        train_generator = train_datagen.flow_from_directory(TRAIN_PATH[ds_idx],
                                                            target_size=IMG_SIZE,
                                                            batch_size=BATCH_SIZE,
                                                            class_mode='categorical',
                                                            shuffle=True,
                                                            subset='training'
                                                            )

        val_generator = train_datagen.flow_from_directory(TRAIN_PATH[ds_idx],
                                                        target_size=IMG_SIZE,
                                                        batch_size=BATCH_SIZE,
                                                        class_mode='categorical',
                                                        shuffle=False,
                                                        subset='validation'
                                                        )
        
        # test_datagen = ImageDataGenerator(rescale=1./255)
        # test_generator = test_datagen.flow_from_directory(TEST_PATH[ds_idx],
        #                                                 target_size=IMG_SIZE,
        #                                                 batch_size=BATCH_SIZE,
        #                                                 class_mode='categorical',
        #                                                 shuffle=False)
        
        print(f"\n::::::::::::::::::::::::::::::::::::::::::::::::::::: Training")

        es = EarlyStopping(monitor="val_accuracy", 
                        mode="max",
                        restore_best_weights=True,
                        patience=6)
        
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', factor=0.3, patience=2, min_lr=0.0000001)
        
        
        int_seed = string_to_int(rs)
        np.random.seed(string_to_int(int_seed))
        tf.random.set_seed(int_seed)

        model = my_ResNet_model(NUM_OF_CLASSES[ds_idx])
        
        hist = model.fit(train_generator,
                        epochs=30,
                        validation_data=val_generator,
                        callbacks=[es, reduce_lr]
                        )

        end_time = time.time()
        elapsed_time = end_time - start_time

        ds_results[ds_idx] = [model, hist,elapsed_time]

    seed_results[rs] = ds_results
# Out:
# ################################################################################### Seed: Georgios | DS: 0
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)
# Found 146 images belonging to 2 classes.
# Found 35 images belonging to 2 classes.
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: Training
# Epoch 1/30
# 5/5 [==============================] - 9s 2s/step - loss: 1.4923 - accuracy: 0.4795 - precision: 0.4795 - recall: 0.4795 - auc: 0.5064 - f1_score: 0.4325 - val_loss: 0.9060 - val_accuracy: 0.6286 - val_precision: 0.6286 - val_recall: 0.6286 - val_auc: 0.7935 - val_f1_score: 0.3860 - lr: 0.0010
# Epoch 2/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.6403 - accuracy: 0.6507 - precision: 0.6507 - recall: 0.6507 - auc: 0.7519 - f1_score: 0.6294 - val_loss: 0.4838 - val_accuracy: 0.8286 - val_precision: 0.8286 - val_recall: 0.8286 - val_auc: 0.8555 - val_f1_score: 0.8273 - lr: 0.0010
# Epoch 3/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.5089 - accuracy: 0.7397 - precision: 0.7397 - recall: 0.7397 - auc: 0.8355 - f1_score: 0.7229 - val_loss: 0.3759 - val_accuracy: 0.7714 - val_precision: 0.7714 - val_recall: 0.7714 - val_auc: 0.9053 - val_f1_score: 0.7200 - lr: 0.0010
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3681 - accuracy: 0.8288 - precision: 0.8288 - recall: 0.8288 - auc: 0.9144 - f1_score: 0.8090 - val_loss: 0.4176 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_auc: 0.9016 - val_f1_score: 0.7974 - lr: 0.0010
# Epoch 5/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3476 - accuracy: 0.8767 - precision: 0.8767 - recall: 0.8767 - auc: 0.9284 - f1_score: 0.8727 - val_loss: 0.3273 - val_accuracy: 0.9143 - val_precision: 0.9143 - val_recall: 0.9143 - val_auc: 0.9355 - val_f1_score: 0.9067 - lr: 0.0010
# Epoch 6/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3174 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9379 - f1_score: 0.8795 - val_loss: 0.3501 - val_accuracy: 0.8857 - val_precision: 0.8857 - val_recall: 0.8857 - val_auc: 0.9241 - val_f1_score: 0.8776 - lr: 0.0010
# Epoch 7/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.2259 - accuracy: 0.9110 - precision: 0.9110 - recall: 0.9110 - auc: 0.9769 - f1_score: 0.9062 - val_loss: 0.3415 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.9257 - val_f1_score: 0.8528 - lr: 0.0010
# Epoch 8/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.2659 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9574 - f1_score: 0.8824 - val_loss: 0.3954 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_auc: 0.9061 - val_f1_score: 0.7822 - lr: 0.0010
# Epoch 9/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.2008 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9777 - f1_score: 0.9125 - val_loss: 0.4829 - val_accuracy: 0.7429 - val_precision: 0.7429 - val_recall: 0.7429 - val_auc: 0.8922 - val_f1_score: 0.7287 - lr: 0.0010
# Epoch 10/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.2394 - accuracy: 0.8836 - precision: 0.8836 - recall: 0.8836 - auc: 0.9653 - f1_score: 0.8756 - val_loss: 0.3337 - val_accuracy: 0.9143 - val_precision: 0.9143 - val_recall: 0.9143 - val_auc: 0.9412 - val_f1_score: 0.9096 - lr: 0.0010
# Epoch 11/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2194 - accuracy: 0.9247 - precision: 0.9247 - recall: 0.9247 - auc: 0.9734 - f1_score: 0.9201 - val_loss: 0.4271 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.9078 - val_f1_score: 0.8493 - lr: 0.0010
#
# ################################################################################### Seed: Georgios | DS: 1
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)
# Found 156 images belonging to 2 classes.
# Found 38 images belonging to 2 classes.
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: Training
# Epoch 1/30
# 5/5 [==============================] - 11s 2s/step - loss: 1.0507 - accuracy: 0.6026 - precision: 0.6026 - recall: 0.6026 - auc: 0.6646 - f1_score: 0.5929 - val_loss: 0.9526 - val_accuracy: 0.5789 - val_precision: 0.5789 - val_recall: 0.5789 - val_auc: 0.6807 - val_f1_score: 0.5476 - lr: 0.0010
# Epoch 2/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.4601 - accuracy: 0.7949 - precision: 0.7949 - recall: 0.7949 - auc: 0.8749 - f1_score: 0.7932 - val_loss: 0.4828 - val_accuracy: 0.7105 - val_precision: 0.7105 - val_recall: 0.7105 - val_auc: 0.8407 - val_f1_score: 0.6722 - lr: 0.0010
# Epoch 3/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2872 - accuracy: 0.8590 - precision: 0.8590 - recall: 0.8590 - auc: 0.9484 - f1_score: 0.8543 - val_loss: 0.5879 - val_accuracy: 0.8158 - val_precision: 0.8158 - val_recall: 0.8158 - val_auc: 0.8428 - val_f1_score: 0.8157 - lr: 0.0010
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2717 - accuracy: 0.8654 - precision: 0.8654 - recall: 0.8654 - auc: 0.9538 - f1_score: 0.8651 - val_loss: 0.4081 - val_accuracy: 0.8158 - val_precision: 0.8158 - val_recall: 0.8158 - val_auc: 0.9017 - val_f1_score: 0.8093 - lr: 0.0010
# Epoch 5/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2989 - accuracy: 0.8654 - precision: 0.8654 - recall: 0.8654 - auc: 0.9463 - f1_score: 0.8574 - val_loss: 0.4100 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9017 - val_f1_score: 0.8403 - lr: 0.0010
# Epoch 6/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2049 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9755 - f1_score: 0.9097 - val_loss: 0.4293 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8975 - val_f1_score: 0.8403 - lr: 0.0010
# Epoch 7/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1614 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9856 - f1_score: 0.9477 - val_loss: 0.3873 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9134 - val_f1_score: 0.8403 - lr: 0.0010
# Epoch 8/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1534 - accuracy: 0.9551 - precision: 0.9551 - recall: 0.9551 - auc: 0.9877 - f1_score: 0.9543 - val_loss: 0.3835 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9211 - val_f1_score: 0.8676 - lr: 0.0010
# Epoch 9/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1167 - accuracy: 0.9615 - precision: 0.9615 - recall: 0.9615 - auc: 0.9947 - f1_score: 0.9611 - val_loss: 0.3407 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9294 - val_f1_score: 0.8638 - lr: 0.0010
# Epoch 10/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1702 - accuracy: 0.9551 - precision: 0.9551 - recall: 0.9551 - auc: 0.9797 - f1_score: 0.9541 - val_loss: 0.2709 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9578 - val_f1_score: 0.8661 - lr: 0.0010
# Epoch 11/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1361 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9890 - f1_score: 0.9354 - val_loss: 0.2953 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9494 - val_f1_score: 0.8676 - lr: 0.0010
# Epoch 12/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0964 - accuracy: 0.9679 - precision: 0.9679 - recall: 0.9679 - auc: 0.9965 - f1_score: 0.9674 - val_loss: 0.1844 - val_accuracy: 0.9211 - val_precision: 0.9211 - val_recall: 0.9211 - val_auc: 0.9799 - val_f1_score: 0.9197 - lr: 3.0000e-04
# Epoch 13/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1054 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9931 - f1_score: 0.9870 - val_loss: 0.3190 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9432 - val_f1_score: 0.8417 - lr: 3.0000e-04
# Epoch 14/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0779 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9991 - f1_score: 0.9738 - val_loss: 0.2722 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9508 - val_f1_score: 0.8676 - lr: 3.0000e-04
# Epoch 15/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1059 - accuracy: 0.9551 - precision: 0.9551 - recall: 0.9551 - auc: 0.9942 - f1_score: 0.9547 - val_loss: 0.3783 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.9252 - val_f1_score: 0.7630 - lr: 3.0000e-04
# Epoch 16/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0997 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9955 - f1_score: 0.9738 - val_loss: 0.2882 - val_accuracy: 0.9211 - val_precision: 0.9211 - val_recall: 0.9211 - val_auc: 0.9522 - val_f1_score: 0.9206 - lr: 9.0000e-05
# Epoch 17/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0604 - accuracy: 0.9808 - precision: 0.9808 - recall: 0.9808 - auc: 0.9993 - f1_score: 0.9805 - val_loss: 0.2287 - val_accuracy: 0.9474 - val_precision: 0.9474 - val_recall: 0.9474 - val_auc: 0.9626 - val_f1_score: 0.9468 - lr: 9.0000e-05
# Epoch 18/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0917 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9972 - f1_score: 0.9741 - val_loss: 0.3566 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9256 - val_f1_score: 0.8417 - lr: 2.7000e-05
# Epoch 19/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0619 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9986 - f1_score: 0.9869 - val_loss: 0.2732 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9578 - val_f1_score: 0.8661 - lr: 2.7000e-05
# Epoch 20/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0692 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9991 - f1_score: 0.9738 - val_loss: 0.3051 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9439 - val_f1_score: 0.8936 - lr: 8.1000e-06
# Epoch 21/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0598 - accuracy: 0.9936 - precision: 0.9936 - recall: 0.9936 - auc: 1.0000 - f1_score: 0.9935 - val_loss: 0.3248 - val_accuracy: 0.9211 - val_precision: 0.9211 - val_recall: 0.9211 - val_auc: 0.9342 - val_f1_score: 0.9197 - lr: 8.1000e-06
# Epoch 22/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0937 - accuracy: 0.9679 - precision: 0.9679 - recall: 0.9679 - auc: 0.9970 - f1_score: 0.9674 - val_loss: 0.2445 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9640 - val_f1_score: 0.8920 - lr: 8.1000e-06
# Epoch 23/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1114 - accuracy: 0.9551 - precision: 0.9551 - recall: 0.9551 - auc: 0.9934 - f1_score: 0.9543 - val_loss: 0.2967 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9460 - val_f1_score: 0.8920 - lr: 8.1000e-06
#
# ################################################################################### Seed: Rafael | DS: 0
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)
# Found 146 images belonging to 2 classes.
# Found 35 images belonging to 2 classes.
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: Training
# Epoch 1/30
# 5/5 [==============================] - 10s 2s/step - loss: 0.8661 - accuracy: 0.5959 - precision: 0.5959 - recall: 0.5959 - auc: 0.6387 - f1_score: 0.5816 - val_loss: 0.4227 - val_accuracy: 0.8286 - val_precision: 0.8286 - val_recall: 0.8286 - val_auc: 0.8922 - val_f1_score: 0.7900 - lr: 0.0010
# Epoch 2/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.6749 - accuracy: 0.7260 - precision: 0.7260 - recall: 0.7260 - auc: 0.7839 - f1_score: 0.7103 - val_loss: 0.3840 - val_accuracy: 0.7714 - val_precision: 0.7714 - val_recall: 0.7714 - val_auc: 0.8971 - val_f1_score: 0.7697 - lr: 0.0010
# Epoch 3/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.5165 - accuracy: 0.7877 - precision: 0.7877 - recall: 0.7877 - auc: 0.8648 - f1_score: 0.7582 - val_loss: 0.3370 - val_accuracy: 0.8857 - val_precision: 0.8857 - val_recall: 0.8857 - val_auc: 0.9355 - val_f1_score: 0.8732 - lr: 0.0010
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.4092 - accuracy: 0.8288 - precision: 0.8288 - recall: 0.8288 - auc: 0.8963 - f1_score: 0.8236 - val_loss: 0.4751 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_auc: 0.8922 - val_f1_score: 0.7993 - lr: 0.0010
# Epoch 5/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3685 - accuracy: 0.8630 - precision: 0.8630 - recall: 0.8630 - auc: 0.9223 - f1_score: 0.8519 - val_loss: 0.4953 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_auc: 0.8857 - val_f1_score: 0.7619 - lr: 0.0010
# Epoch 6/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2552 - accuracy: 0.8699 - precision: 0.8699 - recall: 0.8699 - auc: 0.9606 - f1_score: 0.8587 - val_loss: 0.3420 - val_accuracy: 0.8857 - val_precision: 0.8857 - val_recall: 0.8857 - val_auc: 0.9257 - val_f1_score: 0.8810 - lr: 0.0010
# Epoch 7/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.2895 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9489 - f1_score: 0.8868 - val_loss: 0.2948 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.9469 - val_f1_score: 0.8444 - lr: 0.0010
# Epoch 8/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2522 - accuracy: 0.8836 - precision: 0.8836 - recall: 0.8836 - auc: 0.9612 - f1_score: 0.8736 - val_loss: 0.4239 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.9216 - val_f1_score: 0.8381 - lr: 0.0010
# Epoch 9/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2108 - accuracy: 0.9247 - precision: 0.9247 - recall: 0.9247 - auc: 0.9723 - f1_score: 0.9206 - val_loss: 0.4177 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.9135 - val_f1_score: 0.8493 - lr: 0.0010
#
# ################################################################################### Seed: Rafael | DS: 1
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)
# Found 156 images belonging to 2 classes.
# Found 38 images belonging to 2 classes.
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: Training
# Epoch 1/30
# 5/5 [==============================] - 11s 2s/step - loss: 0.8853 - accuracy: 0.6154 - precision: 0.6154 - recall: 0.6154 - auc: 0.6673 - f1_score: 0.6113 - val_loss: 0.4194 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8934 - val_f1_score: 0.8417 - lr: 0.0010
# Epoch 2/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.5355 - accuracy: 0.7692 - precision: 0.7692 - recall: 0.7692 - auc: 0.8689 - f1_score: 0.7493 - val_loss: 0.4053 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9003 - val_f1_score: 0.8348 - lr: 0.0010
# Epoch 3/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3569 - accuracy: 0.8397 - precision: 0.8397 - recall: 0.8397 - auc: 0.9262 - f1_score: 0.8396 - val_loss: 0.4701 - val_accuracy: 0.7105 - val_precision: 0.7105 - val_recall: 0.7105 - val_auc: 0.8663 - val_f1_score: 0.7103 - lr: 0.0010
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2480 - accuracy: 0.8974 - precision: 0.8974 - recall: 0.8974 - auc: 0.9632 - f1_score: 0.8940 - val_loss: 0.3441 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9273 - val_f1_score: 0.8381 - lr: 0.0010
# Epoch 5/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1788 - accuracy: 0.9295 - precision: 0.9295 - recall: 0.9295 - auc: 0.9855 - f1_score: 0.9282 - val_loss: 0.3940 - val_accuracy: 0.8158 - val_precision: 0.8158 - val_recall: 0.8158 - val_auc: 0.9037 - val_f1_score: 0.8157 - lr: 0.0010
# Epoch 6/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2054 - accuracy: 0.9295 - precision: 0.9295 - recall: 0.9295 - auc: 0.9753 - f1_score: 0.9291 - val_loss: 0.3691 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9211 - val_f1_score: 0.8676 - lr: 0.0010
# Epoch 7/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1675 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9848 - f1_score: 0.9215 - val_loss: 0.3193 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9356 - val_f1_score: 0.8936 - lr: 0.0010
# Epoch 8/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1297 - accuracy: 0.9615 - precision: 0.9615 - recall: 0.9615 - auc: 0.9932 - f1_score: 0.9604 - val_loss: 0.4046 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9145 - val_f1_score: 0.8381 - lr: 3.0000e-04
# Epoch 9/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1066 - accuracy: 0.9615 - precision: 0.9615 - recall: 0.9615 - auc: 0.9970 - f1_score: 0.9610 - val_loss: 0.4162 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9086 - val_f1_score: 0.8403 - lr: 3.0000e-04
# Epoch 10/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1353 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9895 - f1_score: 0.9484 - val_loss: 0.3269 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9425 - val_f1_score: 0.8676 - lr: 3.0000e-04
# Epoch 11/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1041 - accuracy: 0.9936 - precision: 0.9936 - recall: 0.9936 - auc: 0.9977 - f1_score: 0.9935 - val_loss: 0.4294 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9051 - val_f1_score: 0.8381 - lr: 9.0000e-05
# Epoch 12/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1755 - accuracy: 0.9038 - precision: 0.9038 - recall: 0.9038 - auc: 0.9813 - f1_score: 0.9027 - val_loss: 0.4130 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9120 - val_f1_score: 0.8936 - lr: 9.0000e-05
# Epoch 13/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1540 - accuracy: 0.9295 - precision: 0.9295 - recall: 0.9295 - auc: 0.9869 - f1_score: 0.9284 - val_loss: 0.2586 - val_accuracy: 0.9211 - val_precision: 0.9211 - val_recall: 0.9211 - val_auc: 0.9557 - val_f1_score: 0.9197 - lr: 9.0000e-05
# Epoch 14/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1206 - accuracy: 0.9551 - precision: 0.9551 - recall: 0.9551 - auc: 0.9916 - f1_score: 0.9545 - val_loss: 0.3668 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9273 - val_f1_score: 0.8661 - lr: 2.7000e-05
# Epoch 15/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1320 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9907 - f1_score: 0.9477 - val_loss: 0.4585 - val_accuracy: 0.8158 - val_precision: 0.8158 - val_recall: 0.8158 - val_auc: 0.8947 - val_f1_score: 0.8146 - lr: 2.7000e-05
# Epoch 16/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1072 - accuracy: 0.9679 - precision: 0.9679 - recall: 0.9679 - auc: 0.9956 - f1_score: 0.9672 - val_loss: 0.3444 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9349 - val_f1_score: 0.8638 - lr: 8.1000e-06
# Epoch 17/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1129 - accuracy: 0.9551 - precision: 0.9551 - recall: 0.9551 - auc: 0.9945 - f1_score: 0.9541 - val_loss: 0.3805 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9231 - val_f1_score: 0.8381 - lr: 8.1000e-06
# Epoch 18/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1013 - accuracy: 0.9551 - precision: 0.9551 - recall: 0.9551 - auc: 0.9961 - f1_score: 0.9546 - val_loss: 0.3303 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9432 - val_f1_score: 0.8381 - lr: 2.4300e-06
# Epoch 19/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1103 - accuracy: 0.9551 - precision: 0.9551 - recall: 0.9551 - auc: 0.9956 - f1_score: 0.9539 - val_loss: 0.3384 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9373 - val_f1_score: 0.8936 - lr: 2.4300e-06
#
# ################################################################################### Seed: Dimitra | DS: 0
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)
# Found 146 images belonging to 2 classes.
# Found 35 images belonging to 2 classes.
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: Training
# Epoch 1/30
# 5/5 [==============================] - 10s 2s/step - loss: 1.0439 - accuracy: 0.6233 - precision: 0.6233 - recall: 0.6233 - auc: 0.6881 - f1_score: 0.5910 - val_loss: 0.8366 - val_accuracy: 0.5714 - val_precision: 0.5714 - val_recall: 0.5714 - val_auc: 0.6522 - val_f1_score: 0.5585 - lr: 0.0010
# Epoch 2/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.6073 - accuracy: 0.7397 - precision: 0.7397 - recall: 0.7397 - auc: 0.7952 - f1_score: 0.7393 - val_loss: 0.6007 - val_accuracy: 0.6857 - val_precision: 0.6857 - val_recall: 0.6857 - val_auc: 0.8539 - val_f1_score: 0.5727 - lr: 0.0010
# Epoch 3/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.6095 - accuracy: 0.7466 - precision: 0.7466 - recall: 0.7466 - auc: 0.8413 - f1_score: 0.6790 - val_loss: 0.4175 - val_accuracy: 0.8857 - val_precision: 0.8857 - val_recall: 0.8857 - val_auc: 0.8955 - val_f1_score: 0.8810 - lr: 0.0010
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.4881 - accuracy: 0.7808 - precision: 0.7808 - recall: 0.7808 - auc: 0.8637 - f1_score: 0.7798 - val_loss: 0.3372 - val_accuracy: 0.9143 - val_precision: 0.9143 - val_recall: 0.9143 - val_auc: 0.9347 - val_f1_score: 0.9096 - lr: 0.0010
# Epoch 5/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3865 - accuracy: 0.8082 - precision: 0.8082 - recall: 0.8082 - auc: 0.9098 - f1_score: 0.7943 - val_loss: 0.3817 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_auc: 0.9184 - val_f1_score: 0.7734 - lr: 0.0010
# Epoch 6/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2440 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9658 - f1_score: 0.8805 - val_loss: 0.2891 - val_accuracy: 0.8857 - val_precision: 0.8857 - val_recall: 0.8857 - val_auc: 0.9445 - val_f1_score: 0.8776 - lr: 0.0010
# Epoch 7/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3005 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9470 - f1_score: 0.8862 - val_loss: 0.2213 - val_accuracy: 0.9143 - val_precision: 0.9143 - val_recall: 0.9143 - val_auc: 0.9731 - val_f1_score: 0.9096 - lr: 0.0010
# Epoch 8/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2941 - accuracy: 0.8562 - precision: 0.8562 - recall: 0.8562 - auc: 0.9462 - f1_score: 0.8395 - val_loss: 0.3382 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.9322 - val_f1_score: 0.8493 - lr: 0.0010
# Epoch 9/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2698 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9553 - f1_score: 0.8993 - val_loss: 0.2783 - val_accuracy: 0.9143 - val_precision: 0.9143 - val_recall: 0.9143 - val_auc: 0.9543 - val_f1_score: 0.9067 - lr: 3.0000e-04
# Epoch 10/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2288 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9711 - f1_score: 0.9010 - val_loss: 0.2855 - val_accuracy: 0.8857 - val_precision: 0.8857 - val_recall: 0.8857 - val_auc: 0.9510 - val_f1_score: 0.8732 - lr: 3.0000e-04
#
# ################################################################################### Seed: Dimitra | DS: 1
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)
# Found 156 images belonging to 2 classes.
# Found 38 images belonging to 2 classes.
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: Training
# Epoch 1/30
# 5/5 [==============================] - 12s 2s/step - loss: 1.2165 - accuracy: 0.5192 - precision: 0.5192 - recall: 0.5192 - auc: 0.5738 - f1_score: 0.4937 - val_loss: 0.4589 - val_accuracy: 0.7368 - val_precision: 0.7368 - val_recall: 0.7368 - val_auc: 0.8386 - val_f1_score: 0.6955 - lr: 0.0010
# Epoch 2/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.6151 - accuracy: 0.7500 - precision: 0.7500 - recall: 0.7500 - auc: 0.8313 - f1_score: 0.7492 - val_loss: 0.7126 - val_accuracy: 0.7105 - val_precision: 0.7105 - val_recall: 0.7105 - val_auc: 0.7933 - val_f1_score: 0.7054 - lr: 0.0010
# Epoch 3/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.3648 - accuracy: 0.8654 - precision: 0.8654 - recall: 0.8654 - auc: 0.9197 - f1_score: 0.8629 - val_loss: 0.3255 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9266 - val_f1_score: 0.8638 - lr: 0.0010
# Epoch 4/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2468 - accuracy: 0.8974 - precision: 0.8974 - recall: 0.8974 - auc: 0.9625 - f1_score: 0.8945 - val_loss: 0.4477 - val_accuracy: 0.7895 - val_precision: 0.7895 - val_recall: 0.7895 - val_auc: 0.8878 - val_f1_score: 0.7895 - lr: 0.0010
# Epoch 5/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2469 - accuracy: 0.8974 - precision: 0.8974 - recall: 0.8974 - auc: 0.9626 - f1_score: 0.8972 - val_loss: 0.3049 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9432 - val_f1_score: 0.8661 - lr: 0.0010
# Epoch 6/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2097 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9726 - f1_score: 0.9215 - val_loss: 0.3923 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9065 - val_f1_score: 0.8348 - lr: 0.0010
# Epoch 7/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2126 - accuracy: 0.8974 - precision: 0.8974 - recall: 0.8974 - auc: 0.9728 - f1_score: 0.8954 - val_loss: 0.4253 - val_accuracy: 0.8158 - val_precision: 0.8158 - val_recall: 0.8158 - val_auc: 0.9058 - val_f1_score: 0.8157 - lr: 0.0010
# Epoch 8/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1954 - accuracy: 0.9295 - precision: 0.9295 - recall: 0.9295 - auc: 0.9776 - f1_score: 0.9288 - val_loss: 0.3127 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9370 - val_f1_score: 0.8936 - lr: 0.0010
# Epoch 9/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1848 - accuracy: 0.9167 - precision: 0.9167 - recall: 0.9167 - auc: 0.9797 - f1_score: 0.9137 - val_loss: 0.3759 - val_accuracy: 0.7895 - val_precision: 0.7895 - val_recall: 0.7895 - val_auc: 0.9211 - val_f1_score: 0.7889 - lr: 0.0010
# Epoch 10/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1409 - accuracy: 0.9423 - precision: 0.9423 - recall: 0.9423 - auc: 0.9900 - f1_score: 0.9419 - val_loss: 0.3738 - val_accuracy: 0.8684 - val_precision: 0.8684 - val_recall: 0.8684 - val_auc: 0.9204 - val_f1_score: 0.8661 - lr: 0.0010
# Epoch 11/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1383 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9894 - f1_score: 0.9475 - val_loss: 0.2422 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9654 - val_f1_score: 0.8920 - lr: 0.0010
# Epoch 12/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1021 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9948 - f1_score: 0.9739 - val_loss: 0.3164 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9432 - val_f1_score: 0.8417 - lr: 0.0010
# Epoch 13/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.0948 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9979 - f1_score: 0.9741 - val_loss: 0.3589 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9273 - val_f1_score: 0.8920 - lr: 0.0010
# Epoch 14/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1252 - accuracy: 0.9423 - precision: 0.9423 - recall: 0.9423 - auc: 0.9914 - f1_score: 0.9410 - val_loss: 0.2510 - val_accuracy: 0.8947 - val_precision: 0.8947 - val_recall: 0.8947 - val_auc: 0.9626 - val_f1_score: 0.8936 - lr: 0.0010

# %% [markdown]
# ### Plot Histories of all

# %%
plot_training_histories(seed_results)
# Out:
# Seed = Georgios | Dataset index: 0
# Seed = Georgios | Dataset index: 1
# Seed = Rafael | Dataset index: 0
# Seed = Rafael | Dataset index: 1
# Seed = Dimitra | Dataset index: 0
# Seed = Dimitra | Dataset index: 1

# %% [markdown]
# ### Test accuracies and confusion matrices for the trained models

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (6,6))
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    else:   
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
    
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    
    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Hide gridlines
    plt.grid(False)

    plt.show()

# %%
def cal_test_accuracies(seed_data, tst_pth, save2f=''):
    
    tst_acc = []
    
    for sd in list(seed_data.keys()):
        for dset in list(seed_data[sd].keys()):
            
            comb_label = f'Seed = "{sd}" | DS_idx: {dset}\n'
            print(comb_label)

            test_datagen = ImageDataGenerator(rescale=1./255);
            test_generator = test_datagen.flow_from_directory(tst_pth[dset],
                                                            target_size=IMG_SIZE,
                                                            batch_size=BATCH_SIZE,
                                                            class_mode='categorical',
                                                            shuffle=False)
            
            m = seed_data[sd][dset][0];

            y_pred_val_prob = m.predict(test_generator);
            y_pred = np.argmax(y_pred_val_prob, axis=1);
            y_true_val = test_generator.classes;
            test_accuracy = accuracy_score(y_true_val, y_pred);
            tst_acc.append([sd,dset,test_accuracy])
    
            print(f"Test Accuracy = {test_accuracy:.1%}\n")
            print("Classification report:\n", classification_report(y_pred,y_true_val,target_names=CLASS_LABELS[dset]))

            confusion_mtx = confusion_matrix(y_true_val, y_pred) 
            cm = plot_confusion_matrix(confusion_mtx, classes = CLASS_LABELS[dset], title = comb_label, normalize=True)

# %%
cal_test_accuracies(seed_results, TEST_PATH);
# Out:
# Seed = "Georgios" | DS_idx: 0
#
# Found 47 images belonging to 2 classes.
# 2/2 [==============================] - 2s 488ms/step
# Test Accuracy = 89.4%
#
# Classification report:
#                precision    recall  f1-score   support
#
#           no       0.83      0.88      0.86        17
#          yes       0.93      0.90      0.92        30
#
#     accuracy                           0.89        47
#    macro avg       0.88      0.89      0.89        47
# weighted avg       0.90      0.89      0.89        47
# Seed = "Georgios" | DS_idx: 1
#
# Found 49 images belonging to 2 classes.
# 2/2 [==============================] - 2s 556ms/step
# Test Accuracy = 87.8%
#
# Classification report:
#                precision    recall  f1-score   support
#
#  Brain Tumor       0.82      0.96      0.88        24
#      Healthy       0.95      0.80      0.87        25
#
#     accuracy                           0.88        49
#    macro avg       0.89      0.88      0.88        49
# weighted avg       0.89      0.88      0.88        49
# Seed = "Rafael" | DS_idx: 0
#
# Found 47 images belonging to 2 classes.
# 2/2 [==============================] - 2s 503ms/step
# Test Accuracy = 85.1%
#
# Classification report:
#                precision    recall  f1-score   support
#
#           no       0.72      0.87      0.79        15
#          yes       0.93      0.84      0.89        32
#
#     accuracy                           0.85        47
#    macro avg       0.83      0.86      0.84        47
# weighted avg       0.86      0.85      0.85        47
# Seed = "Rafael" | DS_idx: 1
#
# Found 49 images belonging to 2 classes.
# 2/2 [==============================] - 2s 556ms/step
# Test Accuracy = 85.7%
#
# Classification report:
#                precision    recall  f1-score   support
#
#  Brain Tumor       0.86      0.89      0.87        27
#      Healthy       0.86      0.82      0.84        22
#
#     accuracy                           0.86        49
#    macro avg       0.86      0.85      0.85        49
# weighted avg       0.86      0.86      0.86        49
# Seed = "Dimitra" | DS_idx: 0
#
# Found 47 images belonging to 2 classes.
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FEC9B227A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 2s 512ms/step
# Test Accuracy = 91.5%
#
# Classification report:
#                precision    recall  f1-score   support
#
#           no       1.00      0.82      0.90        22
#          yes       0.86      1.00      0.93        25
#
#     accuracy                           0.91        47
#    macro avg       0.93      0.91      0.91        47
# weighted avg       0.93      0.91      0.91        47
# Seed = "Dimitra" | DS_idx: 1
#
# Found 49 images belonging to 2 classes.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001FEB1656840> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 2s 564ms/step
# Test Accuracy = 83.7%
#
# Classification report:
#                precision    recall  f1-score   support
#
#  Brain Tumor       0.86      0.86      0.86        28
#      Healthy       0.81      0.81      0.81        21
#
#     accuracy                           0.84        49
#    macro avg       0.83      0.83      0.83        49
# weighted avg       0.84      0.84      0.84        49

# %% [markdown]
# # END
