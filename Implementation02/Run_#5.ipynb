# %% [markdown]
# ### Importing modules

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import time
import itertools
import pickle
import os

from IPython.display import clear_output

from sklearn.metrics import confusion_matrix , classification_report, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D , MaxPooling2D , Dense , BatchNormalization , Dropout,Flatten , Activation
from tensorflow.keras import regularizers

import tensorflow_addons as tfa

from tensorflow import keras
from keras.applications import ResNet50V2
from keras.layers import Dense, Flatten, GlobalAveragePooling2D, Dropout
from keras.optimizers import Adam
from keras.models import Sequential
from keras.callbacks import EarlyStopping, ReduceLROnPlateau


sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Constants

# %%
# DIRECTORIES

DATASET = []
DATASET.append("./dataset2/Brain Tumor Data Set/Brain Tumor Data Set_pp100")

DATASET_PP = []
TRAIN_PATH = []
TEST_PATH = []
CLASS_LABELS = []
NUM_OF_CLASSES = []


for ii, ds in enumerate(DATASET):
    DATASET_PP.append(ds)
    TRAIN_PATH.append(ds + "/Train")
    TEST_PATH.append(ds + "/Test")
    CLASS_LABELS.append([filename for filename in os.listdir(TRAIN_PATH[ii])])
    NUM_OF_CLASSES.append(len(CLASS_LABELS[ii]))


# OTHER

IMG_SIZE = (244, 244)
BATCH_SIZE = 32

# %%
r_seeds = ["Dimitra"]

# %% [markdown]
# ## Function Definitions

# %% [markdown]
# ### Data Augmentation

# %%
def data_augmentation(r, s):
    # here we will define just the ImageDataGenrator
    # with 0 as the validation split to keep all the images of the traindataset
    # as currently in the train directory
    # we will split this to train-validation sets within the KFold loop

    random.seed(r)

    trn_datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split=s,
        rotation_range=20,          # randomly rotate the images by 20 degrees
        zoom_range=0.2,             # randomly zoom in/out on the images by 20%
        horizontal_flip=True,       # randomly flip the images horizontally
        vertical_flip=False,        # don't flip the images vertically
        width_shift_range=0.1,      # randomly shift the images horizontally by 10%
        height_shift_range=0.1,     # randomly shift the images vertically by 10%
        shear_range=0.1,            # apply random shear transformations
        fill_mode='nearest'         # fill in any empty pixels with the nearest available pixel
        )
    
    return trn_datagen

# %%
def test_data(tst_path, idx, img_size, batch_size):
    # and we can also define the test generator

    tst_datagen = ImageDataGenerator(rescale=1./255)


    tst_generator = tst_datagen.flow_from_directory(tst_path[idx],
                                                    target_size=img_size,
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
    return tst_generator

# %%
def plot_train_history(h, save2f = ''):
    
    hm=['loss', 'accuracy', 'f1_score', 'val_loss', 'val_accuracy', 'val_f1_score']
    e = len(h.history['loss'])

    # Plot metric values for the current seed
    plt.figure(figsize=(12, 6))

    for i in range(6):
        plt.subplot(2, 3, i+1)
        plt.plot(range(1, e+1), h.history[hm[i]], label=hm[i])
        plt.title(hm[i])
        plt.xticks([])
        
        
    plt.tight_layout()
    
    if save2f != '':
        plt.savefig("outputs/" + save2f + ".png")

    plt.show()

# %%
def plot_training_histories(seed_data, save2f=''):
    
    hm=['loss', 'accuracy', 'f1_score', 'val_loss', 'val_accuracy', 'val_f1_score']
    
    for sd in list(seed_data.keys()):
        for dset in list(seed_data[sd].keys()):
            print(f"Seed = {sd} | Dataset index: {dset}")
            h = seed_data[sd][dset][1]
          
            e = len(h.history['loss'])

            # Plot metric values for the current seed
            plt.figure(figsize=(12, 6))

            for i in range(6):
                plt.subplot(2, 3, i+1)
                plt.plot(range(1, e+1), h.history[hm[i]], label=hm[i])
                plt.title(f"{sd} > ds idx : {dset} > {hm[i]}")
                plt.xticks([])
                plt.tight_layout()
                
                if save2f != '':
                    plt.savefig("outputs/" + save2f + ".png")

            plt.show()

# %%
def string_to_int(my_seed):
    
    if isinstance(my_seed, str):
        ascii_values = 0
        for char in my_seed:
            ascii_values += ord(char)
        return int(ascii_values)
    else:
        return my_seed

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## Base Model : ResNet50v2

# %% [markdown]
# ### Model definition

# %%
def my_ResNet_model(c, show_summary=False):
    tf.keras.backend.clear_session()

    base_model = ResNet50V2(input_shape=IMG_SIZE+(3,), include_top=False)
    base_model.trainable = False

    mymodel = Sequential([base_model, 
                          GlobalAveragePooling2D(),
                          Flatten(),
                          Dense(256, activation="relu", kernel_initializer='he_normal'),
                          Dropout(0.3),
                          Dense(c, activation='softmax')
                          ])

    mymodel.compile(optimizer=Adam(), 
                    loss='categorical_crossentropy', 
                    metrics=['accuracy',
                             tf.keras.metrics.Precision(),
                             tf.keras.metrics.Recall(),
                             tf.keras.metrics.AUC(),
                             tfa.metrics.F1Score(num_classes=c, average='macro')
                             ])
    
    if show_summary:
        mymodel.summary()
    
    return mymodel

# %%
# show an example of a model summary for 2 classes
my_ResNet_model(2, show_summary=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 8, 8, 2048)        23564800
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 24089858 (91.90 MB)
# Trainable params: 525058 (2.00 MB)
# Non-trainable params: 23564800 (89.89 MB)
# _________________________________________________________________

# %% [markdown]
# ### Model training for different seeds and datasets

# %%
seed_results = {}

for rs in r_seeds:
    
    ds_results = {}

    for ds_idx in range(len(DATASET)):
        
        start_time = time.time()

        random.seed(rs)
        
        print(f"\n################################################################################### Seed: {rs} | DS: {ds_idx}")
        
        print(f"\n::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)")

        train_datagen = data_augmentation(rs, 0.2) 
        
        train_generator = train_datagen.flow_from_directory(TRAIN_PATH[ds_idx],
                                                            target_size=IMG_SIZE,
                                                            batch_size=BATCH_SIZE,
                                                            class_mode='categorical',
                                                            shuffle=True,
                                                            subset='training'
                                                            )

        val_generator = train_datagen.flow_from_directory(TRAIN_PATH[ds_idx],
                                                        target_size=IMG_SIZE,
                                                        batch_size=BATCH_SIZE,
                                                        class_mode='categorical',
                                                        shuffle=False,
                                                        subset='validation'
                                                        )
        
        # test_datagen = ImageDataGenerator(rescale=1./255)
        # test_generator = test_datagen.flow_from_directory(TEST_PATH[ds_idx],
        #                                                 target_size=IMG_SIZE,
        #                                                 batch_size=BATCH_SIZE,
        #                                                 class_mode='categorical',
        #                                                 shuffle=False)
        
        print(f"\n::::::::::::::::::::::::::::::::::::::::::::::::::::: Training")

        es = EarlyStopping(monitor="val_accuracy", 
                        mode="max",
                        restore_best_weights=True,
                        patience=6)
        
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', factor=0.3, patience=2, min_lr=0.0000001)
        
        
        int_seed = string_to_int(rs)
        np.random.seed(string_to_int(int_seed))
        tf.random.set_seed(int_seed)

        model = my_ResNet_model(NUM_OF_CLASSES[ds_idx])
        
        hist = model.fit(train_generator,
                        epochs=30,
                        validation_data=val_generator,
                        callbacks=[es, reduce_lr]
                        )

        end_time = time.time()
        elapsed_time = end_time - start_time

        ds_results[ds_idx] = [model, hist,elapsed_time]

    seed_results[rs] = ds_results
# Out:
# ################################################################################### Seed: Dimitra | DS: 0
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)
# Found 2596 images belonging to 2 classes.
# Found 648 images belonging to 2 classes.
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: Training
# Epoch 1/30
# 82/82 [==============================] - 128s 2s/step - loss: 0.3625 - accuracy: 0.8475 - precision: 0.8475 - recall: 0.8475 - auc: 0.9261 - f1_score: 0.8443 - val_loss: 0.2659 - val_accuracy: 0.8920 - val_precision: 0.8920 - val_recall: 0.8920 - val_auc: 0.9573 - val_f1_score: 0.8909 - lr: 0.0010
# Epoch 2/30
# 82/82 [==============================] - 130s 2s/step - loss: 0.2123 - accuracy: 0.9183 - precision: 0.9183 - recall: 0.9183 - auc: 0.9718 - f1_score: 0.9168 - val_loss: 0.2299 - val_accuracy: 0.9136 - val_precision: 0.9136 - val_recall: 0.9136 - val_auc: 0.9673 - val_f1_score: 0.9129 - lr: 0.0010
# Epoch 3/30
# 82/82 [==============================] - 128s 2s/step - loss: 0.1683 - accuracy: 0.9353 - precision: 0.9353 - recall: 0.9353 - auc: 0.9825 - f1_score: 0.9340 - val_loss: 0.2071 - val_accuracy: 0.9259 - val_precision: 0.9259 - val_recall: 0.9259 - val_auc: 0.9713 - val_f1_score: 0.9254 - lr: 0.0010
# Epoch 4/30
# 82/82 [==============================] - 141s 2s/step - loss: 0.1533 - accuracy: 0.9441 - precision: 0.9441 - recall: 0.9441 - auc: 0.9852 - f1_score: 0.9431 - val_loss: 0.1738 - val_accuracy: 0.9352 - val_precision: 0.9352 - val_recall: 0.9352 - val_auc: 0.9803 - val_f1_score: 0.9337 - lr: 0.0010
# Epoch 5/30
# 82/82 [==============================] - 140s 2s/step - loss: 0.1199 - accuracy: 0.9553 - precision: 0.9553 - recall: 0.9553 - auc: 0.9912 - f1_score: 0.9545 - val_loss: 0.1605 - val_accuracy: 0.9506 - val_precision: 0.9506 - val_recall: 0.9506 - val_auc: 0.9819 - val_f1_score: 0.9497 - lr: 0.0010
# Epoch 6/30
# 82/82 [==============================] - 137s 2s/step - loss: 0.1296 - accuracy: 0.9549 - precision: 0.9549 - recall: 0.9549 - auc: 0.9891 - f1_score: 0.9540 - val_loss: 0.1767 - val_accuracy: 0.9414 - val_precision: 0.9414 - val_recall: 0.9414 - val_auc: 0.9793 - val_f1_score: 0.9406 - lr: 0.0010
# Epoch 7/30
# 82/82 [==============================] - 140s 2s/step - loss: 0.1057 - accuracy: 0.9615 - precision: 0.9615 - recall: 0.9615 - auc: 0.9927 - f1_score: 0.9607 - val_loss: 0.1963 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9770 - val_f1_score: 0.9286 - lr: 0.0010
# Epoch 8/30
# 82/82 [==============================] - 136s 2s/step - loss: 0.0930 - accuracy: 0.9646 - precision: 0.9646 - recall: 0.9646 - auc: 0.9941 - f1_score: 0.9639 - val_loss: 0.1808 - val_accuracy: 0.9460 - val_precision: 0.9460 - val_recall: 0.9460 - val_auc: 0.9804 - val_f1_score: 0.9451 - lr: 0.0010
# Epoch 9/30
# 82/82 [==============================] - 135s 2s/step - loss: 0.1095 - accuracy: 0.9565 - precision: 0.9565 - recall: 0.9565 - auc: 0.9927 - f1_score: 0.9557 - val_loss: 0.1520 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9856 - val_f1_score: 0.9639 - lr: 0.0010
# Epoch 10/30
# 82/82 [==============================] - 137s 2s/step - loss: 0.0903 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - auc: 0.9934 - f1_score: 0.9682 - val_loss: 0.1506 - val_accuracy: 0.9506 - val_precision: 0.9506 - val_recall: 0.9506 - val_auc: 0.9858 - val_f1_score: 0.9497 - lr: 0.0010
# Epoch 11/30
# 82/82 [==============================] - 131s 2s/step - loss: 0.0922 - accuracy: 0.9622 - precision: 0.9622 - recall: 0.9622 - auc: 0.9946 - f1_score: 0.9615 - val_loss: 0.1890 - val_accuracy: 0.9367 - val_precision: 0.9367 - val_recall: 0.9367 - val_auc: 0.9814 - val_f1_score: 0.9346 - lr: 0.0010
# Epoch 12/30
# 82/82 [==============================] - 136s 2s/step - loss: 0.0676 - accuracy: 0.9750 - precision: 0.9750 - recall: 0.9750 - auc: 0.9972 - f1_score: 0.9745 - val_loss: 0.1422 - val_accuracy: 0.9552 - val_precision: 0.9552 - val_recall: 0.9552 - val_auc: 0.9869 - val_f1_score: 0.9546 - lr: 0.0010
# Epoch 13/30
# 82/82 [==============================] - 141s 2s/step - loss: 0.0857 - accuracy: 0.9653 - precision: 0.9653 - recall: 0.9653 - auc: 0.9949 - f1_score: 0.9647 - val_loss: 0.1537 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583 - val_auc: 0.9844 - val_f1_score: 0.9577 - lr: 0.0010
# Epoch 14/30
# 82/82 [==============================] - 128s 2s/step - loss: 0.0713 - accuracy: 0.9711 - precision: 0.9711 - recall: 0.9711 - auc: 0.9966 - f1_score: 0.9706 - val_loss: 0.1321 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630 - val_auc: 0.9888 - val_f1_score: 0.9622 - lr: 0.0010
# Epoch 15/30
# 82/82 [==============================] - 134s 2s/step - loss: 0.0521 - accuracy: 0.9800 - precision: 0.9800 - recall: 0.9800 - auc: 0.9981 - f1_score: 0.9796 - val_loss: 0.1070 - val_accuracy: 0.9722 - val_precision: 0.9722 - val_recall: 0.9722 - val_auc: 0.9901 - val_f1_score: 0.9717 - lr: 3.0000e-04
# Epoch 16/30
# 82/82 [==============================] - 157s 2s/step - loss: 0.0499 - accuracy: 0.9800 - precision: 0.9800 - recall: 0.9800 - auc: 0.9986 - f1_score: 0.9796 - val_loss: 0.1118 - val_accuracy: 0.9707 - val_precision: 0.9707 - val_recall: 0.9707 - val_auc: 0.9918 - val_f1_score: 0.9702 - lr: 3.0000e-04
# Epoch 17/30
# 82/82 [==============================] - 126s 2s/step - loss: 0.0393 - accuracy: 0.9884 - precision: 0.9884 - recall: 0.9884 - auc: 0.9991 - f1_score: 0.9882 - val_loss: 0.1493 - val_accuracy: 0.9583 - val_precision: 0.9583 - val_recall: 0.9583 - val_auc: 0.9874 - val_f1_score: 0.9577 - lr: 3.0000e-04
# Epoch 18/30
# 82/82 [==============================] - 134s 2s/step - loss: 0.0363 - accuracy: 0.9861 - precision: 0.9861 - recall: 0.9861 - auc: 0.9992 - f1_score: 0.9859 - val_loss: 0.1312 - val_accuracy: 0.9599 - val_precision: 0.9599 - val_recall: 0.9599 - val_auc: 0.9892 - val_f1_score: 0.9593 - lr: 3.0000e-04
# Epoch 19/30
# 82/82 [==============================] - 134s 2s/step - loss: 0.0313 - accuracy: 0.9884 - precision: 0.9884 - recall: 0.9884 - auc: 0.9996 - f1_score: 0.9882 - val_loss: 0.1261 - val_accuracy: 0.9676 - val_precision: 0.9676 - val_recall: 0.9676 - val_auc: 0.9895 - val_f1_score: 0.9671 - lr: 3.0000e-04
# Epoch 20/30
# 82/82 [==============================] - 131s 2s/step - loss: 0.0401 - accuracy: 0.9877 - precision: 0.9877 - recall: 0.9877 - auc: 0.9990 - f1_score: 0.9874 - val_loss: 0.1145 - val_accuracy: 0.9660 - val_precision: 0.9660 - val_recall: 0.9660 - val_auc: 0.9902 - val_f1_score: 0.9654 - lr: 9.0000e-05
# Epoch 21/30
# 82/82 [==============================] - 131s 2s/step - loss: 0.0310 - accuracy: 0.9888 - precision: 0.9888 - recall: 0.9888 - auc: 0.9995 - f1_score: 0.9886 - val_loss: 0.1221 - val_accuracy: 0.9738 - val_precision: 0.9738 - val_recall: 0.9738 - val_auc: 0.9900 - val_f1_score: 0.9733 - lr: 9.0000e-05
# Epoch 22/30
# 82/82 [==============================] - 132s 2s/step - loss: 0.0286 - accuracy: 0.9915 - precision: 0.9915 - recall: 0.9915 - auc: 0.9995 - f1_score: 0.9914 - val_loss: 0.1435 - val_accuracy: 0.9614 - val_precision: 0.9614 - val_recall: 0.9614 - val_auc: 0.9887 - val_f1_score: 0.9607 - lr: 9.0000e-05
# Epoch 23/30
# 82/82 [==============================] - 129s 2s/step - loss: 0.0361 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9989 - f1_score: 0.9851 - val_loss: 0.1082 - val_accuracy: 0.9753 - val_precision: 0.9753 - val_recall: 0.9753 - val_auc: 0.9914 - val_f1_score: 0.9749 - lr: 9.0000e-05
# Epoch 24/30
# 82/82 [==============================] - 128s 2s/step - loss: 0.0270 - accuracy: 0.9908 - precision: 0.9908 - recall: 0.9908 - auc: 0.9996 - f1_score: 0.9906 - val_loss: 0.1253 - val_accuracy: 0.9630 - val_precision: 0.9630 - val_recall: 0.9630 - val_auc: 0.9888 - val_f1_score: 0.9623 - lr: 9.0000e-05
# Epoch 25/30
# 82/82 [==============================] - 130s 2s/step - loss: 0.0284 - accuracy: 0.9911 - precision: 0.9911 - recall: 0.9911 - auc: 0.9996 - f1_score: 0.9910 - val_loss: 0.1356 - val_accuracy: 0.9691 - val_precision: 0.9691 - val_recall: 0.9691 - val_auc: 0.9882 - val_f1_score: 0.9686 - lr: 2.7000e-05
# Epoch 26/30
# 82/82 [==============================] - 132s 2s/step - loss: 0.0250 - accuracy: 0.9923 - precision: 0.9923 - recall: 0.9923 - auc: 0.9997 - f1_score: 0.9922 - val_loss: 0.1067 - val_accuracy: 0.9722 - val_precision: 0.9722 - val_recall: 0.9722 - val_auc: 0.9898 - val_f1_score: 0.9717 - lr: 2.7000e-05
# Epoch 27/30
# 82/82 [==============================] - 130s 2s/step - loss: 0.0279 - accuracy: 0.9915 - precision: 0.9915 - recall: 0.9915 - auc: 0.9996 - f1_score: 0.9914 - val_loss: 0.1263 - val_accuracy: 0.9722 - val_precision: 0.9722 - val_recall: 0.9722 - val_auc: 0.9898 - val_f1_score: 0.9717 - lr: 2.7000e-05
# Epoch 28/30
# 82/82 [==============================] - 134s 2s/step - loss: 0.0225 - accuracy: 0.9915 - precision: 0.9915 - recall: 0.9915 - auc: 0.9998 - f1_score: 0.9914 - val_loss: 0.1257 - val_accuracy: 0.9660 - val_precision: 0.9660 - val_recall: 0.9660 - val_auc: 0.9892 - val_f1_score: 0.9654 - lr: 2.7000e-05
# Epoch 29/30
# 82/82 [==============================] - 132s 2s/step - loss: 0.0268 - accuracy: 0.9908 - precision: 0.9908 - recall: 0.9908 - auc: 0.9997 - f1_score: 0.9906 - val_loss: 0.1233 - val_accuracy: 0.9707 - val_precision: 0.9707 - val_recall: 0.9707 - val_auc: 0.9891 - val_f1_score: 0.9701 - lr: 8.1000e-06

# %% [markdown]
# ### Plot Histories of all

# %%
plot_training_histories(seed_results)
# Out:
# Seed = Dimitra | Dataset index: 0

# %% [markdown]
# ### Test accuracies and confusion matrices for the trained models

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (6,6))
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    else:   
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
    
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    
    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Hide gridlines
    plt.grid(False)

    plt.show()

# %%
def cal_test_accuracies(seed_data, tst_pth, save2f=''):
    
    tst_acc = []
    
    for sd in list(seed_data.keys()):
        for dset in list(seed_data[sd].keys()):
            
            comb_label = f'Seed = "{sd}" | DS_idx: {dset}\n'
            print(comb_label)

            test_datagen = ImageDataGenerator(rescale=1./255);
            test_generator = test_datagen.flow_from_directory(tst_pth[dset],
                                                            target_size=IMG_SIZE,
                                                            batch_size=BATCH_SIZE,
                                                            class_mode='categorical',
                                                            shuffle=False)
            
            m = seed_data[sd][dset][0];

            y_pred_val_prob = m.predict(test_generator);
            y_pred = np.argmax(y_pred_val_prob, axis=1);
            y_true_val = test_generator.classes;
            test_accuracy = accuracy_score(y_true_val, y_pred);
            tst_acc.append([sd,dset,test_accuracy])
    
            print(f"Test Accuracy = {test_accuracy:.1%}\n")
            print("Classification report:\n", classification_report(y_pred,y_true_val,target_names=CLASS_LABELS[dset]))

            confusion_mtx = confusion_matrix(y_true_val, y_pred) 
            cm = plot_confusion_matrix(confusion_mtx, classes = CLASS_LABELS[dset], title = comb_label, normalize=True)

# %%
cal_test_accuracies(seed_results, TEST_PATH);
# Out:
# Seed = "Dimitra" | DS_idx: 0
#
# Found 812 images belonging to 2 classes.
# 26/26 [==============================] - 28s 1s/step
# Test Accuracy = 97.3%
#
# Classification report:
#                precision    recall  f1-score   support
#
#  Brain Tumor       0.98      0.98      0.98       461
#      Healthy       0.97      0.97      0.97       351
#
#     accuracy                           0.97       812
#    macro avg       0.97      0.97      0.97       812
# weighted avg       0.97      0.97      0.97       812

# %% [markdown]
# # END
