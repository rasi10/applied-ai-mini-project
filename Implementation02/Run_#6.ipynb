# %% [markdown]
# ### Importing modules

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import time
import itertools
import pickle
import os

from IPython.display import clear_output

from sklearn.metrics import confusion_matrix , classification_report, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D , MaxPooling2D , Dense , BatchNormalization , Dropout,Flatten , Activation
from tensorflow.keras import regularizers

import tensorflow_addons as tfa

from tensorflow import keras
from keras.applications import ResNet50V2
from keras.layers import Dense, Flatten, GlobalAveragePooling2D, Dropout
from keras.optimizers import Adam
from keras.models import Sequential
from keras.callbacks import EarlyStopping, ReduceLROnPlateau


sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Constants

# %%
# DIRECTORIES

DATASET = []
DATASET.append("./dataset5/Covid19-dataset")
DATASET.append("./dataset6/Cats and Dogs")

DATASET_PP = []
TRAIN_PATH = []
TEST_PATH = []
CLASS_LABELS = []
NUM_OF_CLASSES = []


for ii, ds in enumerate(DATASET):
    DATASET_PP.append(ds)
    TRAIN_PATH.append(ds + "/Train")
    TEST_PATH.append(ds + "/Test")
    CLASS_LABELS.append([filename for filename in os.listdir(TRAIN_PATH[ii]) if os.path.isdir(os.path.join(TRAIN_PATH[ii], filename))])
    
    NUM_OF_CLASSES.append(len(CLASS_LABELS[ii]))



# OTHER

IMG_SIZE = (244, 244)
BATCH_SIZE = 32

# %%
r_seeds = ["D7041E"]

# %% [markdown]
# ## Function Definitions

# %% [markdown]
# ### Data Augmentation

# %%
def data_augmentation(r, s):
    # here we will define just the ImageDataGenrator
    # with 0 as the validation split to keep all the images of the traindataset
    # as currently in the train directory
    # we will split this to train-validation sets within the KFold loop

    random.seed(r)

    trn_datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split=s,
        rotation_range=20,          # randomly rotate the images by 20 degrees
        zoom_range=0.2,             # randomly zoom in/out on the images by 20%
        horizontal_flip=True,       # randomly flip the images horizontally
        vertical_flip=False,        # don't flip the images vertically
        width_shift_range=0.1,      # randomly shift the images horizontally by 10%
        height_shift_range=0.1,     # randomly shift the images vertically by 10%
        shear_range=0.1,            # apply random shear transformations
        fill_mode='nearest'         # fill in any empty pixels with the nearest available pixel
        )
    
    return trn_datagen

# %%
def test_data(tst_path, idx, img_size, batch_size):
    # and we can also define the test generator

    tst_datagen = ImageDataGenerator(rescale=1./255)


    tst_generator = tst_datagen.flow_from_directory(tst_path[idx],
                                                    target_size=img_size,
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    shuffle=False)
    return tst_generator

# %%
def plot_train_history(h, save2f = ''):
    
    hm=['loss', 'accuracy', 'f1_score', 'val_loss', 'val_accuracy', 'val_f1_score']
    e = len(h.history['loss'])

    # Plot metric values for the current seed
    plt.figure(figsize=(12, 6))

    for i in range(6):
        plt.subplot(2, 3, i+1)
        plt.plot(range(1, e+1), h.history[hm[i]], label=hm[i])
        plt.title(hm[i])
        plt.xticks([])
        
        
    plt.tight_layout()
    
    if save2f != '':
        plt.savefig("outputs/" + save2f + ".png")

    plt.show()

# %%
def plot_training_histories(seed_data, save2f=''):
    
    hm=['loss', 'accuracy', 'f1_score', 'val_loss', 'val_accuracy', 'val_f1_score']
    
    for sd in list(seed_data.keys()):
        for dset in list(seed_data[sd].keys()):
            print(f"Seed = {sd} | Dataset index: {dset}")
            h = seed_data[sd][dset][1]
          
            e = len(h.history['loss'])

            # Plot metric values for the current seed
            plt.figure(figsize=(12, 6))

            for i in range(6):
                plt.subplot(2, 3, i+1)
                plt.plot(range(1, e+1), h.history[hm[i]], label=hm[i])
                plt.title(f"{sd} > ds idx : {dset} > {hm[i]}")
                plt.xticks([])
                plt.tight_layout()
                
                if save2f != '':
                    plt.savefig("outputs/" + save2f + ".png")

            plt.show()

# %%
def string_to_int(my_seed):
    
    if isinstance(my_seed, str):
        ascii_values = 0
        for char in my_seed:
            ascii_values += ord(char)
        return int(ascii_values)
    else:
        return my_seed

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ## Base Model : ResNet50v2

# %% [markdown]
# ### Model definition

# %%
def my_ResNet_model(c, show_summary=False):
    tf.keras.backend.clear_session()

    base_model = ResNet50V2(input_shape=IMG_SIZE+(3,), include_top=False)
    base_model.trainable = False

    mymodel = Sequential([base_model, 
                          GlobalAveragePooling2D(),
                          Flatten(),
                          Dense(256, activation="relu", kernel_initializer='he_normal'),
                          Dropout(0.3),
                          Dense(c, activation='softmax')
                          ])

    mymodel.compile(optimizer=Adam(), 
                    loss='categorical_crossentropy', 
                    metrics=['accuracy',
                             tf.keras.metrics.Precision(),
                             tf.keras.metrics.Recall(),
                             tf.keras.metrics.AUC(),
                             tfa.metrics.F1Score(num_classes=c, average='macro')
                             ])
    
    if show_summary:
        mymodel.summary()
    
    return mymodel

# %%
# show an example of a model summary for 3 classes
my_ResNet_model(3, show_summary=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 8, 8, 2048)        23564800
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 24090115 (91.90 MB)
# Trainable params: 525315 (2.00 MB)
# Non-trainable params: 23564800 (89.89 MB)
# _________________________________________________________________

# %% [markdown]
# ### Model training for different seeds and datasets

# %%
seed_results = {}

for rs in r_seeds:
    
    ds_results = {}

    for ds_idx in range(len(DATASET)):
        
        start_time = time.time()

        random.seed(rs)
        
        print(f"\n################################################################################### Seed: {rs} | DS: {ds_idx}")
        
        print(f"\n::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)")

        train_datagen = data_augmentation(rs, 0.2) 
        
        train_generator = train_datagen.flow_from_directory(TRAIN_PATH[ds_idx],
                                                            target_size=IMG_SIZE,
                                                            batch_size=BATCH_SIZE,
                                                            class_mode='categorical',
                                                            shuffle=True,
                                                            subset='training'
                                                            )

        val_generator = train_datagen.flow_from_directory(TRAIN_PATH[ds_idx],
                                                        target_size=IMG_SIZE,
                                                        batch_size=BATCH_SIZE,
                                                        class_mode='categorical',
                                                        shuffle=False,
                                                        subset='validation'
                                                        )
        
        # test_datagen = ImageDataGenerator(rescale=1./255)
        # test_generator = test_datagen.flow_from_directory(TEST_PATH[ds_idx],
        #                                                 target_size=IMG_SIZE,
        #                                                 batch_size=BATCH_SIZE,
        #                                                 class_mode='categorical',
        #                                                 shuffle=False)
        
        print(f"\n::::::::::::::::::::::::::::::::::::::::::::::::::::: Training")

        es = EarlyStopping(monitor="val_accuracy", 
                        mode="max",
                        restore_best_weights=True,
                        patience=6)
        
        reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='accuracy', 
                                                         factor=0.3, 
                                                         patience=2, 
                                                         min_lr=0.0000001)
        
        
        int_seed = string_to_int(rs)
        np.random.seed(string_to_int(int_seed))
        tf.random.set_seed(int_seed)

        model = my_ResNet_model(NUM_OF_CLASSES[ds_idx])
        
        hist = model.fit(train_generator,
                        epochs=30,
                        validation_data=val_generator,
                        callbacks=[es, reduce_lr]
                        )

        end_time = time.time()
        elapsed_time = end_time - start_time

        ds_results[ds_idx] = [model, hist,elapsed_time]

    seed_results[rs] = ds_results
# Out:
# ################################################################################### Seed: D7041E | DS: 0
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)
# Found 200 images belonging to 3 classes.
# Found 48 images belonging to 3 classes.
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: Training
# Epoch 1/30
# 7/7 [==============================] - 20s 3s/step - loss: 1.5061 - accuracy: 0.5700 - precision: 0.5775 - recall: 0.5400 - auc: 0.7225 - f1_score: 0.5387 - val_loss: 0.6400 - val_accuracy: 0.7292 - val_precision: 0.7447 - val_recall: 0.7292 - val_auc: 0.8888 - val_f1_score: 0.7306 - lr: 0.0010
# Epoch 2/30
# 7/7 [==============================] - 11s 2s/step - loss: 0.6041 - accuracy: 0.7550 - precision: 0.7668 - recall: 0.7400 - auc: 0.9122 - f1_score: 0.7351 - val_loss: 0.5986 - val_accuracy: 0.7917 - val_precision: 0.8085 - val_recall: 0.7917 - val_auc: 0.9270 - val_f1_score: 0.7720 - lr: 0.0010
# Epoch 3/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.3229 - accuracy: 0.8500 - precision: 0.8660 - recall: 0.8400 - auc: 0.9702 - f1_score: 0.8350 - val_loss: 0.4647 - val_accuracy: 0.8125 - val_precision: 0.8085 - val_recall: 0.7917 - val_auc: 0.9469 - val_f1_score: 0.8091 - lr: 0.0010
# Epoch 4/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.2368 - accuracy: 0.9100 - precision: 0.9188 - recall: 0.9050 - auc: 0.9845 - f1_score: 0.9020 - val_loss: 0.3175 - val_accuracy: 0.8958 - val_precision: 0.8936 - val_recall: 0.8750 - val_auc: 0.9729 - val_f1_score: 0.8798 - lr: 0.0010
# Epoch 5/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.2755 - accuracy: 0.8950 - precision: 0.9082 - recall: 0.8900 - auc: 0.9785 - f1_score: 0.8814 - val_loss: 0.3754 - val_accuracy: 0.8958 - val_precision: 0.8958 - val_recall: 0.8958 - val_auc: 0.9583 - val_f1_score: 0.8947 - lr: 0.0010
# Epoch 6/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.2083 - accuracy: 0.9100 - precision: 0.9095 - recall: 0.9050 - auc: 0.9878 - f1_score: 0.9006 - val_loss: 0.4385 - val_accuracy: 0.8542 - val_precision: 0.8542 - val_recall: 0.8542 - val_auc: 0.9551 - val_f1_score: 0.8443 - lr: 0.0010
# Epoch 7/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.2140 - accuracy: 0.9200 - precision: 0.9246 - recall: 0.9200 - auc: 0.9859 - f1_score: 0.9131 - val_loss: 0.3633 - val_accuracy: 0.8750 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9645 - val_f1_score: 0.8671 - lr: 3.0000e-04
# Epoch 8/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.1836 - accuracy: 0.9300 - precision: 0.9343 - recall: 0.9250 - auc: 0.9907 - f1_score: 0.9254 - val_loss: 0.2402 - val_accuracy: 0.9583 - val_precision: 0.9574 - val_recall: 0.9375 - val_auc: 0.9773 - val_f1_score: 0.9536 - lr: 3.0000e-04
# Epoch 9/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.1926 - accuracy: 0.9250 - precision: 0.9343 - recall: 0.9250 - auc: 0.9890 - f1_score: 0.9152 - val_loss: 0.2750 - val_accuracy: 0.8958 - val_precision: 0.8936 - val_recall: 0.8750 - val_auc: 0.9766 - val_f1_score: 0.8891 - lr: 3.0000e-04
# Epoch 10/30
# 7/7 [==============================] - 15s 2s/step - loss: 0.1604 - accuracy: 0.9150 - precision: 0.9286 - recall: 0.9100 - auc: 0.9932 - f1_score: 0.9090 - val_loss: 0.2590 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375 - val_auc: 0.9851 - val_f1_score: 0.9270 - lr: 3.0000e-04
# Epoch 11/30
# 7/7 [==============================] - 13s 2s/step - loss: 0.1414 - accuracy: 0.9500 - precision: 0.9500 - recall: 0.9500 - auc: 0.9920 - f1_score: 0.9459 - val_loss: 0.3293 - val_accuracy: 0.9167 - val_precision: 0.9149 - val_recall: 0.8958 - val_auc: 0.9706 - val_f1_score: 0.9176 - lr: 9.0000e-05
# Epoch 12/30
# 7/7 [==============================] - 12s 2s/step - loss: 0.1932 - accuracy: 0.9300 - precision: 0.9394 - recall: 0.9300 - auc: 0.9880 - f1_score: 0.9241 - val_loss: 0.3594 - val_accuracy: 0.8750 - val_precision: 0.8936 - val_recall: 0.8750 - val_auc: 0.9638 - val_f1_score: 0.8615 - lr: 9.0000e-05
# Epoch 13/30
# 7/7 [==============================] - 13s 2s/step - loss: 0.1544 - accuracy: 0.9550 - precision: 0.9596 - recall: 0.9500 - auc: 0.9912 - f1_score: 0.9492 - val_loss: 0.2868 - val_accuracy: 0.8958 - val_precision: 0.8958 - val_recall: 0.8958 - val_auc: 0.9803 - val_f1_score: 0.8865 - lr: 9.0000e-05
# Epoch 14/30
# 7/7 [==============================] - 13s 2s/step - loss: 0.1730 - accuracy: 0.9350 - precision: 0.9397 - recall: 0.9350 - auc: 0.9915 - f1_score: 0.9264 - val_loss: 0.2851 - val_accuracy: 0.9167 - val_precision: 0.9565 - val_recall: 0.9167 - val_auc: 0.9755 - val_f1_score: 0.9121 - lr: 9.0000e-05
#
# ################################################################################### Seed: D7041E | DS: 1
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: (Train, Val)
# Found 220 images belonging to 2 classes.
# Found 55 images belonging to 2 classes.
#
# ::::::::::::::::::::::::::::::::::::::::::::::::::::: Training
# Epoch 1/30
# 7/7 [==============================] - 18s 2s/step - loss: 0.3622 - accuracy: 0.8409 - precision: 0.8409 - recall: 0.8409 - auc: 0.9279 - f1_score: 0.8246 - val_loss: 0.0115 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 0.0010
# Epoch 2/30
# 7/7 [==============================] - 11s 2s/step - loss: 0.0253 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909 - auc: 0.9997 - f1_score: 0.9899 - val_loss: 0.0153 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 0.0010
# Epoch 3/30
# 7/7 [==============================] - 11s 2s/step - loss: 0.0233 - accuracy: 0.9864 - precision: 0.9864 - recall: 0.9864 - auc: 0.9997 - f1_score: 0.9849 - val_loss: 0.0068 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 0.0010
# Epoch 4/30
# 7/7 [==============================] - 11s 2s/step - loss: 0.0059 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - f1_score: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 0.0010
# Epoch 5/30
# 7/7 [==============================] - 11s 2s/step - loss: 0.0165 - accuracy: 0.9955 - precision: 0.9955 - recall: 0.9955 - auc: 0.9998 - f1_score: 0.9950 - val_loss: 0.0063 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 0.0010
# Epoch 6/30
# 7/7 [==============================] - 11s 2s/step - loss: 0.0223 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909 - auc: 0.9996 - f1_score: 0.9899 - val_loss: 0.0123 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 0.0010
# Epoch 7/30
# 7/7 [==============================] - 11s 2s/step - loss: 0.0294 - accuracy: 0.9909 - precision: 0.9909 - recall: 0.9909 - auc: 0.9998 - f1_score: 0.9899 - val_loss: 0.0146 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 3.0000e-04

# %% [markdown]
# ### Plot Histories of all

# %%
plot_training_histories(seed_results)
# Out:
# Seed = D7041E | Dataset index: 0
# Seed = D7041E | Dataset index: 1

# %% [markdown]
# ### Test accuracies and confusion matrices for the trained models

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (6,6))
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        plt.imshow(cm, interpolation='nearest', cmap=cmap, vmin=0, vmax=1)
    else:   
        plt.imshow(cm, interpolation='nearest', cmap=cmap)
    
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    
    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    # Hide gridlines
    plt.grid(False)

    plt.show()

# %%
def cal_test_accuracies(seed_data, tst_pth, save2f=''):
    
    tst_acc = []
    
    for sd in list(seed_data.keys()):
        for dset in list(seed_data[sd].keys()):
            
            comb_label = f'Seed = "{sd}" | DS_idx: {dset}\n'
            print(comb_label)

            test_datagen = ImageDataGenerator(rescale=1./255);
            test_generator = test_datagen.flow_from_directory(tst_pth[dset],
                                                            target_size=IMG_SIZE,
                                                            batch_size=BATCH_SIZE,
                                                            class_mode='categorical',
                                                            shuffle=False)
            
            m = seed_data[sd][dset][0];

            y_pred_val_prob = m.predict(test_generator);
            y_pred = np.argmax(y_pred_val_prob, axis=1);
            y_true_val = test_generator.classes;
            test_accuracy = accuracy_score(y_true_val, y_pred);
            tst_acc.append([sd,dset,test_accuracy])
    
            print(f"Test Accuracy = {test_accuracy:.1%}\n")
            print("Classification report:\n", classification_report(y_pred,y_true_val,target_names=CLASS_LABELS[dset]))

            confusion_mtx = confusion_matrix(y_true_val, y_pred) 
            cm = plot_confusion_matrix(confusion_mtx, classes = CLASS_LABELS[dset], title = comb_label, normalize=True)

# %%
cal_test_accuracies(seed_results, TEST_PATH);
# Out:
# Seed = "D7041E" | DS_idx: 0
#
# Found 65 images belonging to 3 classes.
# 3/3 [==============================] - 4s 928ms/step
# Test Accuracy = 92.3%
#
# Classification report:
#                   precision    recall  f1-score   support
#
#           Covid       0.92      1.00      0.96        23
#          Normal       0.95      0.86      0.90        22
# Viral Pneumonia       0.90      0.90      0.90        20
#
#        accuracy                           0.92        65
#       macro avg       0.92      0.92      0.92        65
#    weighted avg       0.92      0.92      0.92        65
# Seed = "D7041E" | DS_idx: 1
#
# Found 70 images belonging to 2 classes.
# 3/3 [==============================] - 3s 863ms/step
# Test Accuracy = 98.6%
#
# Classification report:
#                precision    recall  f1-score   support
#
#          cat       0.96      1.00      0.98        23
#          dog       1.00      0.98      0.99        47
#
#     accuracy                           0.99        70
#    macro avg       0.98      0.99      0.98        70
# weighted avg       0.99      0.99      0.99        70

# %% [markdown]
# # END
